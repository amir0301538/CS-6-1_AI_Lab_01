# %%
print("Hello World")
# Out:
# Hello World

# %%
x = input("Enter your name")
print(x)
# Out:
# Enter your nameAamir
# Aamir

# %%
name = input("Enter your friends name")
age = input("Enter your friends age")
interest = input("Enter your friends interest")
nationality = input("ENter your friends nationality")

print(name, age, interest, nationality)
# Out:
# Enter your friends nameAgha
# Enter your friends age21
# Enter your friends interestgaming
# ENter your friends nationalityPakistan
# Agha 21 gaming Pakistan

# %%
num = int(input("Enter a number: "))

if (num % 2) == 0:
   print("It is Even")
else:
   print("It is Odd")
# Out:
# Enter a number: 3
# It is Odd

# %%
15/4
# Out:
# 3.75

# %%
15//4
# Out:
# 3

# %%
def greeting():

  num = int(input("Enter a number: "))

  if (num % 2) == 0:
    print("It is Even")
  else:
    print("It is Odd")

# %%
greeting()
# Out:
# Enter a number: 4
# It is Even

# %%
def frienddetails():
    name = input("Enter your friends name")
    age = input("Enter your friends age")
    interest = input("Enter your friends interest")
    nationality = input("ENter your friends nationality")
    print(name, age, interest, nationality)
    print(name, age, interest, nationality)
    print(name, age, interest, nationality)
    print(name, age, interest, nationality)
    print(name, age, interest, nationality)

# %%
frienddetails()
# Out:
# Enter your friends nameagha
# Enter your friends age21
# Enter your friends interestgame
# ENter your friends nationalitypaki
# agha 21 game paki
# agha 21 game paki
# agha 21 game paki
# agha 21 game paki
# agha 21 game paki

# %%
greeting = ("Aoa")

for i in range (0,10):
  print(greeting)
# Out:
# Aoa
# Aoa
# Aoa
# Aoa
# Aoa
# Aoa
# Aoa
# Aoa
# Aoa
# Aoa

# %%
num = int(input("Enter a number: "))

for i in range(1, 11):
   print(num, "*", i, "=", num * i)
# Out:
# Enter a number: 5
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %%
def is_prime(n):
    if n == 0 or n == 1:
        return 0
    else:
        for i in range(2, n):
            if n % i == 0:
                return 0
    return 1

# %%
x = int (input("Enter a number"))
if is_prime(x)==0:
    print ("number is not prime")
else :
    print("number is prime")
# Out:
# Enter a number6
# number is not prime

# %%
count = 1
for i in range(100):
    if is_prime(i) == 1:
        print(count, "\t", i)
        if count >= 20:
            break
        count += 1
# Out:
# 1 	 2
# 2 	 3
# 3 	 5
# 4 	 7
# 5 	 11
# 6 	 13
# 7 	 17
# 8 	 19
# 9 	 23
# 10 	 29
# 11 	 31
# 12 	 37
# 13 	 41
# 14 	 43
# 15 	 47
# 16 	 53
# 17 	 59
# 18 	 61
# 19 	 67
# 20 	 71

# %%
square = lambda x:x*x*x

# %%
for i in range (10):
  print (square(i))
# Out:
# 0
# 1
# 8
# 27
# 64
# 125
# 216
# 343
# 512
# 729
